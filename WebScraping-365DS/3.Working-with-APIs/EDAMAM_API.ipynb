# %% [markdown]
# - Authentification before using API is a common thing.
# - It allows the developpers to control over the usage of their product.
# - Also, it may allow them to upgrade and personalize their service

# %% [markdown]
# # The nutritional and recipe analysis API of 'EDAMAM'

# %% [markdown]
# ### Initial Setup

# %%
import requests
import json

# %%
APP_ID = "e1a3d071"
APP_KEY = "039e040d208e32ab7f21bcffe9bd2382"

# %%
api_endpoint = "https://api.edamam.com/api/nutrition-details"

url = api_endpoint + "?app_id="  + APP_ID + "&app_key=" + APP_KEY

# %% [markdown]
# * "This API returns the nutritional information based on a POST request of the recipe content. The POST request submits the recipe content, specifically the recipe title and ingredient list. The response the API returns, will contain the nutritional analysis for the recipe based on the information provided." (refer to the API documentation)

# %% [markdown]
# * The equivalent to username and password in the context of APIs are ID and key

# %% [markdown]
# ## Sending a POST request

# %% [markdown]
# * This API expects a POST request and not a GET request. The main difference between those types of requests is that the parameters in a POST request are contained in a separate body, rather than directly encoded in the URL

# %%
# The headers provide information about the request itself
# Based on the documentation of the API: we must state that the data we send, is in a JSON format through the 'Content-Type' header
# for clear structuring we create a variable for the header:
headers = {
    'Content-Type' : 'application/json'
}

# %%
recipe = {
    'Title' : 'Cappuccino',
    'ingr' : ['18g ground espresso', '150ml milk']
}

# %% [markdown]
# * We make the POST request by just replacing the `.get()` method with `.post()`

# %%
r = requests.post(url, headers = headers, json = recipe)
r.status_code
# Out:
# 200

# %% [markdown]
# -> The server response means that the request and parameters are submitted correctly.

# %% [markdown]
# ## Inspecting the response

# %%
capp_info = r.json()
print(json.dumps(capp_info, indent = 4))
# Out:
# {
#     "uri": "http://www.edamam.com/ontologies/edamam.owl#recipe_5f8f7e88a370452b99e37fa0c0c9ff1e",
#     "yield": 2.0,
#     "calories": 95,
#     "totalCO2Emissions": 503.921462750041,
#     "co2EmissionsClass": "C",
#     "totalWeight": 172.69915386093172,
#     "dietLabels": [
#         "LOW_SODIUM"
#     ],
#     "healthLabels": [
#         "LOW_FAT_ABS",
#         "SUGAR_CONSCIOUS",
#         "LOW_POTASSIUM",
#         "KIDNEY_FRIENDLY",
#         "KETO_FRIENDLY",
#         "VEGETARIAN",
#         "PESCATARIAN",
#         "MEDITERRANEAN",
#         "GLUTEN_FREE",
#         "WHEAT_FREE",
#         "EGG_FREE",
#         "PEANUT_FREE",
#         "TREE_NUT_FREE",
#         "SOY_FREE",
#         "FISH_FREE",
#         "SHELLFISH_FREE",
#         "PORK_FREE",
#         "RED_MEAT_FREE",
#         "CRUSTACEAN_FREE",
#         "CELERY_FREE",
#         "MUSTARD_FREE",
#         "SESAME_FREE",
#         "LUPINE_FREE",
#         "MOLLUSK_FREE",
#         "ALCOHOL_FREE",
#         "NO_OIL_ADDED",
#         "NO_SUGAR_ADDED",
#         "SULPHITE_FREE",
#         "KOSHER"
#     ],
#     "cautions": [
#         "SULFITES"
#     ],
#     "totalNutrients": {
#         "ENERC_KCAL": {
#             "label": "Energy",
#             "quantity": 95.98648385516834,
#             "unit": "kcal"
#         },
#         "FAT": {
#             "label": "Total lipid (fat)",
#             "quantity": 5.060122500480281,
#             "unit": "g"
#         },
#         "FASAT": {
#             "label": "Fatty acids, total saturated",
#             "quantity": 2.89396426181333,
#             "unit": "g"
#         },
#         "FATRN": {
#             "label": "Fatty acids, total trans",
#             "quantity": 0.0,
#             "unit": "g"
#         },
#         "FAMS": {
#             "label": "Fatty acids, total monounsaturated",
#             "quantity": 1.2561571293507656,
#             "unit": "g"
#         },
#         "FAPU": {
#             "label": "Fatty acids, total polyunsaturated",
#             "quantity": 0.31822335002881685,
#             "unit": "g"
#         },
#         "CHOCDF": {
#             "label": "Carbohydrate, by difference",
#             "quantity": 7.726159385324722,
#             "unit": "g"
#         },
#         "CHOCDF.net": {
#             "label": "Carbohydrates (net)",
#             "quantity": 7.726159385324722,
#             "unit": "g"
#         },
#         "FIBTG": {
#             "label": "Fiber, total dietary",
#             "quantity": 0.0,
#             "unit": "g"
#         },
#         "SUGAR": {
#             "label": "Sugars, total including NLEA",
#             "quantity": 7.812307269977051,
#             "unit": "g"
#         },
#         "PROCNT": {
#             "label": "Protein",
#             "quantity": 4.894623346619349,
#             "unit": "g"
#         },
#         "CHOLE": {
#             "label": "Cholesterol",
#             "quantity": 15.469915386093172,
#             "unit": "mg"
#         },
#         "NA": {
#             "label": "Sodium, Na",
#             "quantity": 69.04063616020063,
#             "unit": "mg"
#         },
#         "CA": {
#             "label": "Calcium, Ca",
#             "quantity": 175.17004386285285,
#             "unit": "mg"
#         },
#         "MG": {
#             "label": "Magnesium, Mg",
#             "quantity": 29.86991538609317,
#             "unit": "mg"
#         },
#         "K": {
#             "label": "Potassium, K",
#             "quantity": 224.90288309642986,
#             "unit": "mg"
#         },
#         "FE": {
#             "label": "Iron, Fe",
#             "quantity": 0.06980974615827952,
#             "unit": "mg"
#         },
#         "ZN": {
#             "label": "Zinc, Zn",
#             "quantity": 0.5813868692854474,
#             "unit": "mg"
#         },
#         "P": {
#             "label": "Phosphorus, P",
#             "quantity": 131.20728924318263,
#             "unit": "mg"
#         },
#         "VITA_RAE": {
#             "label": "Vitamin A, RAE",
#             "quantity": 71.1616107760286,
#             "unit": "\u00b5g"
#         },
#         "VITC": {
#             "label": "Vitamin C, total ascorbic acid",
#             "quantity": 0.036,
#             "unit": "mg"
#         },
#         "THIA": {
#             "label": "Thiamin",
#             "quantity": 0.07134161077602859,
#             "unit": "mg"
#         },
#         "RIBF": {
#             "label": "Riboflavin",
#             "quantity": 0.2933015700249746,
#             "unit": "mg"
#         },
#         "NIA": {
#             "label": "Niacin",
#             "quantity": 1.0754822469362293,
#             "unit": "mg"
#         },
#         "VITB6A": {
#             "label": "Vitamin B-6",
#             "quantity": 0.056051695389935416,
#             "unit": "mg"
#         },
#         "FOLDFE": {
#             "label": "Folate, DFE",
#             "quantity": 7.914957693046586,
#             "unit": "\u00b5g"
#         },
#         "FOLFD": {
#             "label": "Folate, food",
#             "quantity": 7.914957693046586,
#             "unit": "\u00b5g"
#         },
#         "FOLAC": {
#             "label": "Folic acid",
#             "quantity": 0.0,
#             "unit": "\u00b5g"
#         },
#         "VITB12": {
#             "label": "Vitamin B-12",
#             "quantity": 0.6961461923741927,
#             "unit": "\u00b5g"
#         },
#         "VITD": {
#             "label": "Vitamin D (D2 + D3)",
#             "quantity": 2.0110890001921122,
#             "unit": "\u00b5g"
#         },
#         "TOCPHA": {
#             "label": "Vitamin E (alpha-tocopherol)",
#             "quantity": 0.1100894077026522,
#             "unit": "mg"
#         },
#         "VITK1": {
#             "label": "Vitamin K (phylloquinone)",
#             "quantity": 0.48209746158279515,
#             "unit": "\u00b5g"
#         },
#         "WATER": {
#             "label": "Water",
#             "quantity": 153.89395455148082,
#             "unit": "g"
#         }
#     },
#     "totalDaily": {
#         "ENERC_KCAL": {
#             "label": "Energy",
#             "quantity": 4.799324192758418,
#             "unit": "%"
#         },
#         "FAT": {
#             "label": "Fat",
#             "quantity": 7.78480384689274,
#             "unit": "%"
#         },
#         "FASAT": {
#             "label": "Saturated",
#             "quantity": 14.469821309066651,
#             "unit": "%"
#         },
#         "CHOCDF": {
#             "label": "Carbs",
#             "quantity": 2.5753864617749076,
#             "unit": "%"
#         },
#         "FIBTG": {
#             "label": "Fiber",
#             "quantity": 0.0,
#             "unit": "%"
#         },
#         "PROCNT": {
#             "label": "Protein",
#             "quantity": 9.789246693238699,
#             "unit": "%"
#         },
#         "CHOLE": {
#             "label": "Cholesterol",
#             "quantity": 5.156638462031057,
#             "unit": "%"
#         },
#         "NA": {
#             "label": "Sodium",
#             "quantity": 2.8766931733416934,
#             "unit": "%"
#         },
#         "CA": {
#             "label": "Calcium",
#             "quantity": 17.517004386285283,
#             "unit": "%"
#         },
#         "MG": {
#             "label": "Magnesium",
#             "quantity": 7.11188461573647,
#             "unit": "%"
#         },
#         "K": {
#             "label": "Potassium",
#             "quantity": 4.785167725455954,
#             "unit": "%"
#         },
#         "FE": {
#             "label": "Iron",
#             "quantity": 0.3878319231015529,
#             "unit": "%"
#         },
#         "ZN": {
#             "label": "Zinc",
#             "quantity": 5.285335175322249,
#             "unit": "%"
#         },
#         "P": {
#             "label": "Phosphorus",
#             "quantity": 18.743898463311805,
#             "unit": "%"
#         },
#         "VITA_RAE": {
#             "label": "Vitamin A",
#             "quantity": 7.906845641780954,
#             "unit": "%"
#         },
#         "VITC": {
#             "label": "Vitamin C",
#             "quantity": 0.039999999999999994,
#             "unit": "%"
#         },
#         "THIA": {
#             "label": "Thiamin (B1)",
#             "quantity": 5.945134231335716,
#             "unit": "%"
#         },
#         "RIBF": {
#             "label": "Riboflavin (B2)",
#             "quantity": 22.561659232690353,
#             "unit": "%"
#         },
#         "NIA": {
#             "label": "Niacin (B3)",
#             "quantity": 6.721764043351433,
#             "unit": "%"
#         },
#         "VITB6A": {
#             "label": "Vitamin B6",
#             "quantity": 4.311668876148878,
#             "unit": "%"
#         },
#         "FOLDFE": {
#             "label": "Folate equivalent (total)",
#             "quantity": 1.9787394232616464,
#             "unit": "%"
#         },
#         "VITB12": {
#             "label": "Vitamin B12",
#             "quantity": 29.0060913489247,
#             "unit": "%"
#         },
#         "VITD": {
#             "label": "Vitamin D",
#             "quantity": 13.407260001280749,
#             "unit": "%"
#         },
#         "TOCPHA": {
#             "label": "Vitamin E",
#             "quantity": 0.733929384684348,
#             "unit": "%"
#         },
#         "VITK1": {
#             "label": "Vitamin K",
#             "quantity": 0.4017478846523293,
#             "unit": "%"
#         }
#     },
#     "ingredients": [
#         {
#             "text": "18g ground espresso",
#             "parsed": [
#                 {
#                     "quantity": 18.0,
#                     "measure": "gram",
#                     "foodMatch": "espresso",
#                     "food": "espresso",
#                     "foodId": "food_bwvztweawd5emqbcu3dqua2ts9ol",
#                     "weight": 18.0,
#                     "retainedWeight": 18.0,
#                     "nutrients": {
#                         "RIBF": {
#                             "label": "Riboflavin",
#                             "quantity": 0.03186,
#                             "unit": "mg"
#                         },
#                         "VITD": {
#                             "label": "Vitamin D (D2 + D3), International Units",
#                             "quantity": 0.0,
#                             "unit": "IU"
#                         },
#                         "THIA": {
#                             "label": "Thiamin",
#                             "quantity": 0.00018,
#                             "unit": "mg"
#                         },
#                         "FAPU": {
#                             "label": "Fatty acids, total polyunsaturated",
#                             "quantity": 0.01656,
#                             "unit": "g"
#                         },
#                         "FATRN": {
#                             "label": "Fatty acids, total trans",
#                             "quantity": 0.0,
#                             "unit": "g"
#                         },
#                         "NIA": {
#                             "label": "Niacin",
#                             "quantity": 0.9378,
#                             "unit": "mg"
#                         },
#                         "ENERC_KCAL": {
#                             "label": "Energy",
#                             "quantity": 1.62,
#                             "unit": "kcal"
#                         },
#                         "FASAT": {
#                             "label": "Fatty acids, total saturated",
#                             "quantity": 0.01656,
#                             "unit": "g"
#                         },
#                         "VITA_RAE": {
#                             "label": "Vitamin A, RAE",
#                             "quantity": 0.0,
#                             "unit": "\u00b5g"
#                         },
#                         "VITC": {
#                             "label": "Vitamin C, total ascorbic acid",
#                             "quantity": 0.036000000000000004,
#                             "unit": "mg"
#                         },
#                         "PROCNT": {
#                             "label": "Protein",
#                             "quantity": 0.0216,
#                             "unit": "g"
#                         },
#                         "TOCPHA": {
#                             "label": "Vitamin E (alpha-tocopherol)",
#                             "quantity": 0.0018,
#                             "unit": "mg"
#                         },
#                         "CHOLE": {
#                             "label": "Cholesterol",
#                             "quantity": 0.0,
#                             "unit": "mg"
#                         },
#                         "FAMS": {
#                             "label": "Fatty acids, total monounsaturated",
#                             "quantity": 0.0,
#                             "unit": "g"
#                         },
#                         "CHOCDF": {
#                             "label": "Carbohydrate, by difference",
#                             "quantity": 0.3006,
#                             "unit": "g"
#                         },
#                         "FAT": {
#                             "label": "Total lipid (fat)",
#                             "quantity": 0.0324,
#                             "unit": "g"
#                         },
#                         "VITB6A": {
#                             "label": "Vitamin B-6",
#                             "quantity": 0.00036,
#                             "unit": "mg"
#                         },
#                         "VITB12": {
#                             "label": "Vitamin B-12",
#                             "quantity": 0.0,
#                             "unit": "\u00b5g"
#                         },
#                         "FIBTG": {
#                             "label": "Fiber, total dietary",
#                             "quantity": 0.0,
#                             "unit": "g"
#                         },
#                         "WATER": {
#                             "label": "Water",
#                             "quantity": 17.604,
#                             "unit": "g"
#                         },
#                         "K": {
#                             "label": "Potassium, K",
#                             "quantity": 20.7,
#                             "unit": "mg"
#                         },
#                         "P": {
#                             "label": "Phosphorus, P",
#                             "quantity": 1.26,
#                             "unit": "mg"
#                         },
#                         "NA": {
#                             "label": "Sodium, Na",
#                             "quantity": 2.52,
#                             "unit": "mg"
#                         },
#                         "ZN": {
#                             "label": "Zinc, Zn",
#                             "quantity": 0.009000000000000001,
#                             "unit": "mg"
#                         },
#                         "SUGAR": {
#                             "label": "Sugars, total including NLEA",
#                             "quantity": 0.0,
#                             "unit": "g"
#                         },
#                         "CA": {
#                             "label": "Calcium, Ca",
#                             "quantity": 0.36,
#                             "unit": "mg"
#                         },
#                         "MG": {
#                             "label": "Magnesium, Mg",
#                             "quantity": 14.4,
#                             "unit": "mg"
#                         },
#                         "FE": {
#                             "label": "Iron, Fe",
#                             "quantity": 0.023399999999999997,
#                             "unit": "mg"
#                         },
#                         "VITK1": {
#                             "label": "Vitamin K (phylloquinone)",
#                             "quantity": 0.018000000000000002,
#                             "unit": "\u00b5g"
#                         },
#                         "FOLFD": {
#                             "label": "Folate, food",
#                             "quantity": 0.18,
#                             "unit": "\u00b5g"
#                         },
#                         "FOLAC": {
#                             "label": "Folic acid",
#                             "quantity": 0.0,
#                             "unit": "\u00b5g"
#                         },
#                         "FOLDFE": {
#                             "label": "Folate, DFE",
#                             "quantity": 0.18,
#                             "unit": "\u00b5g"
#                         }
#                     },
#                     "measureURI": "http://www.edamam.com/ontologies/edamam.owl#Measure_gram",
#                     "status": "OK"
#                 }
#             ]
#         },
#         {
#             "text": "150ml milk",
#             "parsed": [
#                 {
#                     "quantity": 150.0,
#                     "measure": "milliliter",
#                     "foodMatch": "milk",
#                     "food": "whole milk",
#                     "foodId": "food_b49rs1kaw0jktabzkg2vvanvvsis",
#                     "weight": 154.69915386093172,
#                     "retainedWeight": 154.69915386093172,
#                     "nutrients": {
#                         "VITD": {
#                             "label": "Vitamin D (D2 + D3), International Units",
#                             "quantity": 78.89656846907518,
#                             "unit": "IU"
#                         },
#                         "ENERC_KCAL": {
#                             "label": "Energy",
#                             "quantity": 94.36648385516835,
#                             "unit": "kcal"
#                         },
#                         "FASAT": {
#                             "label": "Fatty acids, total saturated",
#                             "quantity": 2.8774042618133304,
#                             "unit": "g"
#                         },
#                         "VITA_RAE": {
#                             "label": "Vitamin A, RAE",
#                             "quantity": 71.1616107760286,
#                             "unit": "\u00b5g"
#                         },
#                         "PROCNT": {
#                             "label": "Protein",
#                             "quantity": 4.873023346619349,
#                             "unit": "g"
#                         },
#                         "TOCPHA": {
#                             "label": "Vitamin E (alpha-tocopherol)",
#                             "quantity": 0.10828940770265222,
#                             "unit": "mg"
#                         },
#                         "CHOLE": {
#                             "label": "Cholesterol",
#                             "quantity": 15.46991538609317,
#                             "unit": "mg"
#                         },
#                         "CHOCDF": {
#                             "label": "Carbohydrate, by difference",
#                             "quantity": 7.425559385324721,
#                             "unit": "g"
#                         },
#                         "FAT": {
#                             "label": "Total lipid (fat)",
#                             "quantity": 5.027722500480281,
#                             "unit": "g"
#                         },
#                         "FIBTG": {
#                             "label": "Fiber, total dietary",
#                             "quantity": 0.0,
#                             "unit": "g"
#                         },
#                         "RIBF": {
#                             "label": "Riboflavin",
#                             "quantity": 0.2614415700249746,
#                             "unit": "mg"
#                         },
#                         "THIA": {
#                             "label": "Thiamin",
#                             "quantity": 0.07116161077602859,
#                             "unit": "mg"
#                         },
#                         "FAPU": {
#                             "label": "Fatty acids, total polyunsaturated",
#                             "quantity": 0.30166335002881683,
#                             "unit": "g"
#                         },
#                         "NIA": {
#                             "label": "Niacin",
#                             "quantity": 0.1376822469362292,
#                             "unit": "mg"
#                         },
#                         "VITC": {
#                             "label": "Vitamin C, total ascorbic acid",
#                             "quantity": 0.0,
#                             "unit": "mg"
#                         },
#                         "FAMS": {
#                             "label": "Fatty acids, total monounsaturated",
#                             "quantity": 1.2561571293507656,
#                             "unit": "g"
#                         },
#                         "VITB6A": {
#                             "label": "Vitamin B-6",
#                             "quantity": 0.05569169538993541,
#                             "unit": "mg"
#                         },
#                         "VITB12": {
#                             "label": "Vitamin B-12",
#                             "quantity": 0.6961461923741927,
#                             "unit": "\u00b5g"
#                         },
#                         "WATER": {
#                             "label": "Water",
#                             "quantity": 136.28995455148083,
#                             "unit": "g"
#                         },
#                         "K": {
#                             "label": "Potassium, K",
#                             "quantity": 204.20288309642987,
#                             "unit": "mg"
#                         },
#                         "P": {
#                             "label": "Phosphorus, P",
#                             "quantity": 129.94728924318264,
#                             "unit": "mg"
#                         },
#                         "NA": {
#                             "label": "Sodium, Na",
#                             "quantity": 66.52063616020064,
#                             "unit": "mg"
#                         },
#                         "ZN": {
#                             "label": "Zinc, Zn",
#                             "quantity": 0.5723868692854474,
#                             "unit": "mg"
#                         },
#                         "SUGAR": {
#                             "label": "Sugars, total including NLEA",
#                             "quantity": 7.812307269977051,
#                             "unit": "g"
#                         },
#                         "CA": {
#                             "label": "Calcium, Ca",
#                             "quantity": 174.81004386285284,
#                             "unit": "mg"
#                         },
#                         "MG": {
#                             "label": "Magnesium, Mg",
#                             "quantity": 15.46991538609317,
#                             "unit": "mg"
#                         },
#                         "FE": {
#                             "label": "Iron, Fe",
#                             "quantity": 0.04640974615827951,
#                             "unit": "mg"
#                         },
#                         "VITK1": {
#                             "label": "Vitamin K (phylloquinone)",
#                             "quantity": 0.4640974615827951,
#                             "unit": "\u00b5g"
#                         },
#                         "FOLFD": {
#                             "label": "Folate, food",
#                             "quantity": 7.734957693046585,
#                             "unit": "\u00b5g"
#                         },
#                         "FOLAC": {
#                             "label": "Folic acid",
#                             "quantity": 0.0,
#                             "unit": "\u00b5g"
#                         },
#                         "FOLDFE": {
#                             "label": "Folate, DFE",
#                             "quantity": 7.734957693046585,
#                             "unit": "\u00b5g"
#                         }
#                     },
#                     "measureURI": "http://www.edamam.com/ontologies/edamam.owl#Measure_milliliter",
#                     "status": "OK"
#                 }
#             ]
#         }
#     ],
#     "cuisineType": [
#         "french"
#     ],
#     "mealType": [
#         "breakfast"
#     ],
#     "dishType": [
#         "cereals"
#     ],
#     "totalNutrientsKCal": {
#         "ENERC_KCAL": {
#             "label": "Energy",
#             "quantity": 97,
#             "unit": "kcal"
#         },
#         "PROCNT_KCAL": {
#             "label": "Calories from protein",
#             "quantity": 20,
#             "unit": "kcal"
#         },
#         "FAT_KCAL": {
#             "label": "Calories from fat",
#             "quantity": 46,
#             "unit": "kcal"
#         },
#         "CHOCDF_KCAL": {
#             "label": "Calories from carbohydrates",
#             "quantity": 31,
#             "unit": "kcal"
#         }
#     }
# }

# %%
capp_info.keys()
# Out:
# dict_keys(['uri', 'yield', 'calories', 'totalCO2Emissions', 'co2EmissionsClass', 'totalWeight', 'dietLabels', 'healthLabels', 'cautions', 'totalNutrients', 'totalDaily', 'ingredients', 'cuisineType', 'mealType', 'dishType', 'totalNutrientsKCal'])

# %%
print(json.dumps(capp_info["totalNutrients"], indent =4))
# Out:
# {
#     "ENERC_KCAL": {
#         "label": "Energy",
#         "quantity": 95.98648385516834,
#         "unit": "kcal"
#     },
#     "FAT": {
#         "label": "Total lipid (fat)",
#         "quantity": 5.060122500480281,
#         "unit": "g"
#     },
#     "FASAT": {
#         "label": "Fatty acids, total saturated",
#         "quantity": 2.89396426181333,
#         "unit": "g"
#     },
#     "FATRN": {
#         "label": "Fatty acids, total trans",
#         "quantity": 0.0,
#         "unit": "g"
#     },
#     "FAMS": {
#         "label": "Fatty acids, total monounsaturated",
#         "quantity": 1.2561571293507656,
#         "unit": "g"
#     },
#     "FAPU": {
#         "label": "Fatty acids, total polyunsaturated",
#         "quantity": 0.31822335002881685,
#         "unit": "g"
#     },
#     "CHOCDF": {
#         "label": "Carbohydrate, by difference",
#         "quantity": 7.726159385324722,
#         "unit": "g"
#     },
#     "CHOCDF.net": {
#         "label": "Carbohydrates (net)",
#         "quantity": 7.726159385324722,
#         "unit": "g"
#     },
#     "FIBTG": {
#         "label": "Fiber, total dietary",
#         "quantity": 0.0,
#         "unit": "g"
#     },
#     "SUGAR": {
#         "label": "Sugars, total including NLEA",
#         "quantity": 7.812307269977051,
#         "unit": "g"
#     },
#     "PROCNT": {
#         "label": "Protein",
#         "quantity": 4.894623346619349,
#         "unit": "g"
#     },
#     "CHOLE": {
#         "label": "Cholesterol",
#         "quantity": 15.469915386093172,
#         "unit": "mg"
#     },
#     "NA": {
#         "label": "Sodium, Na",
#         "quantity": 69.04063616020063,
#         "unit": "mg"
#     },
#     "CA": {
#         "label": "Calcium, Ca",
#         "quantity": 175.17004386285285,
#         "unit": "mg"
#     },
#     "MG": {
#         "label": "Magnesium, Mg",
#         "quantity": 29.86991538609317,
#         "unit": "mg"
#     },
#     "K": {
#         "label": "Potassium, K",
#         "quantity": 224.90288309642986,
#         "unit": "mg"
#     },
#     "FE": {
#         "label": "Iron, Fe",
#         "quantity": 0.06980974615827952,
#         "unit": "mg"
#     },
#     "ZN": {
#         "label": "Zinc, Zn",
#         "quantity": 0.5813868692854474,
#         "unit": "mg"
#     },
#     "P": {
#         "label": "Phosphorus, P",
#         "quantity": 131.20728924318263,
#         "unit": "mg"
#     },
#     "VITA_RAE": {
#         "label": "Vitamin A, RAE",
#         "quantity": 71.1616107760286,
#         "unit": "\u00b5g"
#     },
#     "VITC": {
#         "label": "Vitamin C, total ascorbic acid",
#         "quantity": 0.036,
#         "unit": "mg"
#     },
#     "THIA": {
#         "label": "Thiamin",
#         "quantity": 0.07134161077602859,
#         "unit": "mg"
#     },
#     "RIBF": {
#         "label": "Riboflavin",
#         "quantity": 0.2933015700249746,
#         "unit": "mg"
#     },
#     "NIA": {
#         "label": "Niacin",
#         "quantity": 1.0754822469362293,
#         "unit": "mg"
#     },
#     "VITB6A": {
#         "label": "Vitamin B-6",
#         "quantity": 0.056051695389935416,
#         "unit": "mg"
#     },
#     "FOLDFE": {
#         "label": "Folate, DFE",
#         "quantity": 7.914957693046586,
#         "unit": "\u00b5g"
#     },
#     "FOLFD": {
#         "label": "Folate, food",
#         "quantity": 7.914957693046586,
#         "unit": "\u00b5g"
#     },
#     "FOLAC": {
#         "label": "Folic acid",
#         "quantity": 0.0,
#         "unit": "\u00b5g"
#     },
#     "VITB12": {
#         "label": "Vitamin B-12",
#         "quantity": 0.6961461923741927,
#         "unit": "\u00b5g"
#     },
#     "VITD": {
#         "label": "Vitamin D (D2 + D3)",
#         "quantity": 2.0110890001921122,
#         "unit": "\u00b5g"
#     },
#     "TOCPHA": {
#         "label": "Vitamin E (alpha-tocopherol)",
#         "quantity": 0.1100894077026522,
#         "unit": "mg"
#     },
#     "VITK1": {
#         "label": "Vitamin K (phylloquinone)",
#         "quantity": 0.48209746158279515,
#         "unit": "\u00b5g"
#     },
#     "WATER": {
#         "label": "Water",
#         "quantity": 153.89395455148082,
#         "unit": "g"
#     }
# }

# %%
capp_info["totalNutrients"]["SUGAR"]
# Out:
# {'label': 'Sugars, total including NLEA',
#  'quantity': 7.812307269977051,
#  'unit': 'g'}

# %% [markdown]
# ## Structuring and exporting the data

# %%
import pandas as pd

pd.DataFrame(capp_info["totalNutrients"])
# Out:
#          ENERC_KCAL                FAT                         FASAT  \
# label        Energy  Total lipid (fat)  Fatty acids, total saturated
# quantity  95.986484           5.060123                      2.893964
# unit           kcal                  g                             g
#
#                              FATRN                                FAMS  \
# label     Fatty acids, total trans  Fatty acids, total monounsaturated
# quantity                       0.0                            1.256157
# unit                             g                                   g
#
#                                         FAPU                       CHOCDF  \
# label     Fatty acids, total polyunsaturated  Carbohydrate, by difference
# quantity                            0.318223                     7.726159
# unit                                       g                            g
#
#                    CHOCDF.net                 FIBTG  \
# label     Carbohydrates (net)  Fiber, total dietary
# quantity             7.726159                   0.0
# unit                        g                     g
#
#                                  SUGAR  ...       NIA       VITB6A  \
# label     Sugars, total including NLEA  ...    Niacin  Vitamin B-6
# quantity                      7.812307  ...  1.075482     0.056052
# unit                                 g  ...        mg           mg
#
#                FOLDFE         FOLFD       FOLAC        VITB12  \
# label     Folate, DFE  Folate, food  Folic acid  Vitamin B-12
# quantity     7.914958      7.914958         0.0      0.696146
# unit               µg            µg          µg            µg
#
#                          VITD                        TOCPHA  \
# label     Vitamin D (D2 + D3)  Vitamin E (alpha-tocopherol)
# quantity             2.011089                      0.110089
# unit                       µg                            mg
#
#                               VITK1       WATER
# label     Vitamin K (phylloquinone)       Water
# quantity                   0.482097  153.893955
# unit                             µg           g
#
# [3 rows x 33 columns]

# %% [markdown]
# * It would be better if we can flip it to be vertical. This can be achieved with the `.transpose()` method

# %%
capp_nutrients = pd.DataFrame(capp_info["totalNutrients"]).transpose()
capp_nutrients
# Out:
#                                          label    quantity  unit
# ENERC_KCAL                              Energy   95.986484  kcal
# FAT                          Total lipid (fat)    5.060123     g
# FASAT             Fatty acids, total saturated    2.893964     g
# FATRN                 Fatty acids, total trans         0.0     g
# FAMS        Fatty acids, total monounsaturated    1.256157     g
# FAPU        Fatty acids, total polyunsaturated    0.318223     g
# CHOCDF             Carbohydrate, by difference    7.726159     g
# CHOCDF.net                 Carbohydrates (net)    7.726159     g
# FIBTG                     Fiber, total dietary         0.0     g
# SUGAR             Sugars, total including NLEA    7.812307     g
# PROCNT                                 Protein    4.894623     g
# CHOLE                              Cholesterol   15.469915    mg
# NA                                  Sodium, Na   69.040636    mg
# CA                                 Calcium, Ca  175.170044    mg
# MG                               Magnesium, Mg   29.869915    mg
# K                                 Potassium, K  224.902883    mg
# FE                                    Iron, Fe     0.06981    mg
# ZN                                    Zinc, Zn    0.581387    mg
# P                                Phosphorus, P  131.207289    mg
# VITA_RAE                        Vitamin A, RAE   71.161611    µg
# VITC            Vitamin C, total ascorbic acid       0.036    mg
# THIA                                   Thiamin    0.071342    mg
# RIBF                                Riboflavin    0.293302    mg
# NIA                                     Niacin    1.075482    mg
# VITB6A                             Vitamin B-6    0.056052    mg
# FOLDFE                             Folate, DFE    7.914958    µg
# FOLFD                             Folate, food    7.914958    µg
# FOLAC                               Folic acid         0.0    µg
# VITB12                            Vitamin B-12    0.696146    µg
# VITD                       Vitamin D (D2 + D3)    2.011089    µg
# TOCPHA            Vitamin E (alpha-tocopherol)    0.110089    mg
# VITK1                Vitamin K (phylloquinone)    0.482097    µg
# WATER                                    Water  153.893955     g

# %%
capp_nutrients.to_csv("Cappuccino_nutrients.csv")

# %% [markdown]
# ## Testing invalid input

# %%
cake = requests.post(url, headers = headers, json = {"title": "Cheesecake"})
cake.status_code
# Out:
# 400

# %%
cake.json()
# Out:
# {'error': 'bad_request', 'message': "Missing 'ingr'"}

# %% [markdown]
# ## Downloading files with Requests

# %% [markdown]
# * **The naive approach**: the CSV files we exported can be viewed as a download. Following the same logic, this way of downloading consists of first connecting to the page and catching the response, and then exporting the content of the reply. This method first download the file to the RAM and only then it is written on the Hard Drive.
# * The notebook "downloading files with requests" explore how to stream the download so that it can be written in chunks and introduces the Python `with` statement.
